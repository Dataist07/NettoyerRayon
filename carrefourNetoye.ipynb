# %%
import csv
import pandas as pd
from datetime import date

month = '4'
today = date.today()
year = today.year


dfSupermarket= pd.read_csv(f'/Users/minh/Desktop/Comparator/Scrap/Data_base/{year}/{month}/drivesScraped/list_drives_carrefourScraped.csv', dtype={"department": str})

for i,supermarket in enumerate(dfSupermarket['supermarket']):
    department = dfSupermarket.iloc[i]["department"]
    city = dfSupermarket.iloc[i]["city"]
    dateScraped= dfSupermarket.iloc[i]["date_scraped"]
    nom_drive = dfSupermarket.iloc[i]["nom_drive"]

    dfProduits = pd.read_csv(f'/Users/minh/Desktop/Comparator/Scrap/Data_base/{year}/{month}/{department}/{city}/{nom_drive}/{dateScraped}/{supermarket}_produits.csv')
    # 1
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Fruits et Légumes', 'Fruits, légumes') 
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Mon marché frais') & (dfProduits['rayon_secondaire'] == 'Mon Primeur'), 'rayon_principal'] = 'Fruits, légumes'
    #2
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Viandes et Poissons', 'Viandes, poissons')
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Mon marché frais') & (dfProduits['rayon_secondaire'] == 'Mon Boucher'), 'rayon_principal'] = 'Viandes, poissons'
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Mon marché frais') & (dfProduits['rayon_secondaire'] == 'Mon Poissonnier'), 'rayon_principal'] = 'Viandes, poissons'
    #3
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Charcuterie et Traiteur', 'Charcuterie, traiteur')
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Mon marché frais') & (dfProduits['rayon_secondaire'] == 'Mon Charcutier'), 'rayon_principal'] = 'Charcuterie, traiteur'
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Mon marché frais') & (dfProduits['rayon_secondaire'] == 'Mon Traiteur'), 'rayon_principal'] = 'Charcuterie, traiteur'
    #4
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Pains et Pâtisseries', 'Pain, pâtisserie')
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Mon marché frais') & (dfProduits['rayon_secondaire'] == 'Mon Boulanger'), 'rayon_principal'] = 'Pain, pâtisserie'
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Mon marché frais') & (dfProduits['rayon_secondaire'] == 'Mon Pâtissier'), 'rayon_principal'] = 'Pain, pâtisserie'
    #5
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Crèmerie et Produits laitiers', 'Produits laitiers, oeufs, fromages')
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Mon marché frais') & (dfProduits['rayon_secondaire'] == 'Mon Fromager'), 'rayon_principal'] = 'Produits laitiers, oeufs, fromages'
    #6
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Bio et Ecologie', 'Bio')
    #7
    #8
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Epicerie sucrée', 'Épicerie sucrée')
    #9
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Epicerie salée', 'Épicerie salée')
    #10
    #11
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Produits régionaux et locaux') & (dfProduits['rayon_secondaire'] == 'Le meilleur de ma région'), 'rayon_principal'] = 'Produits du monde'
    dfProduits.loc[(dfProduits['rayon_principal'] == 'Produits régionaux et locaux') & (dfProduits['rayon_secondaire'] == 'Toutes nos régions'), 'rayon_principal'] = 'Produits du monde'
    #12
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Nutrition et Végétale', 'Nutrition, végétale')
    #13
    #14
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Hygiène et Beauté', 'Hygiène, beauté')
    #15
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Entretien et Nettoyage', 'Entretien, nettoyage')
    #16
    dfProduits['rayon_principal'] = dfProduits['rayon_principal'].replace('Animalerie', 'Animal')

    # Save the modified DataFrame (optional)
    dfProduits.to_csv(f'/Users/minh/Desktop/Comparator/Scrap/Data_base/{year}/{month}/{department}/{city}/{nom_drive}/{dateScraped}/{supermarket}_produitsNetoye.csv', index=False)  # Adjust path as needed
